# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewB01/Personal_Finances/blob/main/notebooks/Personal_Expenses_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Create Dataframe from Expenses analysis.xlsx file**

# %%
df = pd.read_excel('Expenses analysis.xlsx', sheet_name=None)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# **List all sheets within the Excel file**

# %%
# Print all sheet names
df.keys()
# Out:
# dict_keys(['raw data', 'billing data', 'Hoja1', 'Hoja2'])

# %% [markdown]
# **Especify data sets for Raw Data and Billing Data sheets**

# %%
rd = df['raw data']
bd = df['billing data']

# %% [markdown]
# **Review table content and structure rd => Raw Data**

# %%
 rd.head()
# Out:
#     Day Month       Date                     Item    Price    Store  QTY  \
# 0  vie.   oct 2023-10-13                      ajo   1163.0  Fruvar     1
# 1  vie.   oct 2023-10-13  cebolla cabezona blanca   2145.0  Fruvar     1
# 2  vie.   oct 2023-10-13                 pimenton   1296.0  Fruvar     1
# 3  vie.   oct 2023-10-13            tomate chonto   3528.0  Fruvar     1
# 4  vie.   oct 2023-10-13            manzana verde  29637.0  Fruvar     1
#
#             Type    Total
# 0  Food Shopping   1163.0
# 1  Food Shopping   2145.0
# 2  Food Shopping   1296.0
# 3  Food Shopping   3528.0
# 4  Food Shopping  29637.0

# %% [markdown]
# **Adjust table to match billing data table structure, reduce granularity by grouping Store and date**

# %%
rd = rd.groupby(['Store', 'Date']).agg({'Total': 'sum', 'Type': 'first'})
rd = rd.reset_index()
rd = rd[['Date', 'Store', 'Type', 'Total']]
rd
# Out:
#           Date             Store            Type     Total
# 0   2024-08-10            Alpina      Restaurant    7500.0
# 1   2024-09-06    American Eagle            Gift  375840.0
# 2   2024-08-30  Aportes en linea      Healthcare  386100.0
# 3   2024-08-30             Apple    Entretaiment   12900.0
# 4   2024-10-01               Ara   Food Shopping  201336.0
# ..         ...               ...             ...       ...
# 532 2024-06-22            cabify  Transportation   46892.0
# 533 2024-06-25            cabify  Transportation   28721.0
# 534 2024-07-05            cabify  Transportation   11366.0
# 535 2023-11-18        dollarcity   Food Shopping   52000.0
# 536 2023-12-29            tostao   Food Shopping   23100.0
#
# [537 rows x 4 columns]

# %% [markdown]
# **Adjust columns dropping unnecesary tables to match Raw Data Tables**

# %%
bd = bd.drop(columns=['Day', 'Month', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'])
bd
# Out:
#           Date       Store            Type  Total
# 0   2024-09-14      Cabify  Transportation  16401
# 1   2024-09-15      Cabify  Transportation  16030
# 2   2024-09-15      Cabify  Transportation  19072
# 3   2024-09-15      Cabify  Transportation  15528
# 4   2024-09-15      Cabify  Transportation   9925
# ..         ...         ...             ...    ...
# 574 2025-03-13         NaN           Snack   2600
# 575 2025-03-14        Oxxo           Snack   6900
# 576 2025-03-15        Oxxo           Snack   7400
# 577 2025-11-03  El Chocolo           Snack  10800
# 578 2025-12-03     Puppies        Dog food  73749
#
# [579 rows x 4 columns]

# %% [markdown]
# **Review data types for Raw data and Billing data**

# %%
bd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    579 non-null    datetime64[ns]
#  1   Store   547 non-null    object
#  2   Type    560 non-null    object
#  3   Total   579 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 18.2+ KB

# %%
rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    537 non-null    datetime64[ns]
#  1   Store   537 non-null    object
#  2   Type    535 non-null    object
#  3   Total   537 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 16.9+ KB

# %% [markdown]
# **Change Total column data type from Billing Data dataframe to match Raw Data dataframe**

# %%
bd['Total'] = bd['Total'].astype('float64')

# %% [markdown]
# **Union Billing and Raw Dataframes**

# %%
raw_df = pd.concat([rd, bd], ignore_index=True)
raw_df
# Out:
#            Date             Store           Type     Total
# 0    2024-08-10            Alpina     Restaurant    7500.0
# 1    2024-09-06    American Eagle           Gift  375840.0
# 2    2024-08-30  Aportes en linea     Healthcare  386100.0
# 3    2024-08-30             Apple   Entretaiment   12900.0
# 4    2024-10-01               Ara  Food Shopping  201336.0
# ...         ...               ...            ...       ...
# 1111 2025-03-13               NaN          Snack    2600.0
# 1112 2025-03-14              Oxxo          Snack    6900.0
# 1113 2025-03-15              Oxxo          Snack    7400.0
# 1114 2025-11-03        El Chocolo          Snack   10800.0
# 1115 2025-12-03           Puppies       Dog food   73749.0
#
# [1116 rows x 4 columns]

# %% [markdown]
# **Transform Store and Type data to lower case and remove spaces to the right and left**

# %%
raw_df['Store'] = raw_df['Store'].str.strip().str.lower()
raw_df['Type'] = raw_df['Type'].str.strip().str.lower()
raw_df
# Out:
#            Date             Store           Type     Total
# 0    2024-08-10            alpina     restaurant    7500.0
# 1    2024-09-06    american eagle           gift  375840.0
# 2    2024-08-30  aportes en linea     healthcare  386100.0
# 3    2024-08-30             apple   entretaiment   12900.0
# 4    2024-10-01               ara  food shopping  201336.0
# ...         ...               ...            ...       ...
# 1111 2025-03-13               nan          snack    2600.0
# 1112 2025-03-14              oxxo          snack    6900.0
# 1113 2025-03-15              oxxo          snack    7400.0
# 1114 2025-11-03        el chocolo          snack   10800.0
# 1115 2025-12-03           puppies       dog food   73749.0
#
# [1116 rows x 4 columns]

# %%
raw_df_relation = raw_df.groupby(['Type', 'Store']).size().reset_index(name='Count')

raw_df_relation
# Out:
#           Type        Store  Count
# 0         agua         agua      1
# 1       beauty     barberia      2
# 2       beauty    mustaches      1
# 3       beauty   peluqueria      1
# 4       brunch  grand hyatt      1
# ..         ...          ...    ...
# 281  utilities         tigo      2
# 282  utilities        vanti      3
# 283    utility         enel      1
# 284    utility         tigo      1
# 285    utility        vanti      1
#
# [286 rows x 3 columns]

# %% [markdown]
# **Sort Store information and display unique values to identify misppeling and similar errors**

# %%
raw_df = raw_df.sort_values(by=['Store'])
raw_df_relation = raw_df['Store'].unique()
raw_df_relation
# Out:
# array(['acueducto', 'admon tds', 'agua', 'alparke', 'alpina',
#        'amazon.com', 'american cheese cake', 'american eagle',
#        'andres dc', 'aportes en linea', 'ara', 'archies',
#        'arepas y embueltos', 'arreglo bici', 'aseo', 'bacu', 'bagel shop',
#        'barberia', 'baskin robbins', 'bono colsanitas', 'bono eps',
#        'bono medisanitas', 'bono sanitas', 'brasa roja', 'brissa',
#        'bubu burger', 'buffalo Wings', 'buffalo wings', 'burger king',
#        'cabify', 'cafe quindio', 'canva', 'car renting',
#        'carbon & xilvestre', 'carbon place', 'carulla', 'casa ideas',
#        'casa paella', 'central parking', 'certificado l&t',
#        'charlotte pasteleria', 'cinecolombia', 'cinema viziona',
#        'cinemark', 'cinepolis', 'clase dibujo', 'clinica del colon',
#        'coctel del mar', 'coliseo live', 'colo colo café', 'colsanitas',
#        'colsubsidio', 'comercial papelera', 'compensar', 'corral gourmet',
#        'corrientaso', 'cosette', 'crepes & waffles', 'cruz verde', 'd1',
#        'daflores', 'data camp', 'decathalon', 'deli', 'diner', 'disney+',
#        'dollarcity', 'dominos', 'don rome', 'don romero', 'donut factory',
#        'dorotea', 'drogeria egs', 'drogeria san remo', 'drogeria titan',
#        'dunkin donuts', 'easy', 'eds la texana', 'el carnal',
#        'el cañon del chicamocha', 'el chocolo', 'el chocolo de katerin',
#        'el corral', 'emermedica', 'enel', 'eps premium', 'etb', 'exito',
#        'falabella', 'farmatodo', 'festa fin de año 2024',
#        'fillet station', 'foodology', 'fruvar', 'fruver', 'fullcarga',
#        'fusion urban food', 'godo burger', 'gordo bar', 'gorro ingrid',
#        'goyurt', 'grand hyatt', 'guatoque', 'guiacereza', 'gurus', 'h&m',
#        'hornitos', 'icloud', 'inkanta', 'juan valdez', 'jumbo',
#        'jungla park', 'ko', 'kutty', 'la biferia', 'la birra del gordo',
#        'la lucha sangucheria', 'la taqueria', 'la tienda papelera',
#        'la75', 'lasgatas', 'le grand mamma', 'le patissier',
#        'little caesar', 'mad radio', 'massaje', 'max', 'mazorcas',
#        'mcdonalds', 'medicines', 'medisanitas', 'mercadolibre',
#        'mercados de boyaca', 'merengazo', 'michelle', 'microsoft',
#        'milagros', 'minca', 'miniso', 'mis carnes parrilla', 'monimo',
#        'morrillos', 'mr bono', 'mustaches', 'nan', 'natural light',
#        'nectaria', 'obleas la villa', 'oma', 'oxxo', 'palos de leña',
#        'pan pa ya', 'panamericana', 'papa johns', 'paramarte', 'parking',
#        'paseo archie', 'passaro', 'pelupet', 'peluqueria', 'petgourmet',
#        'phone accesories', 'pizza hut', 'popsy', 'prestamo', 'pricesmart',
#        'proteina', 'puppies', 'randys', 'rappi', 'reserva tramonti',
#        'rey guerrero', 'sbarro', 'semolina', 'sipote burrito', 'smartfit',
#        'spining center', 'spotify', 'starbucks', 'steak', 'street bao',
#        'street food', 'subway', 'suizo pontevedra', 'super liquidator',
#        'sushi nogal', 'tickets feria automovil', 'tienda dietetica',
#        'tienda libertario cafe', 'tienda palera', 'tigo', 'tipicas',
#        'torta francesa', 'tostao', 'toysmart', 'transmilenio',
#        'tu arte, tu vino', 'tuboleta', 'uber', 'vanti', 'vending machine',
#        'verona', 'vitalhome', 'wahaka', 'whopperking', 'wok', 'zara'],
#       dtype=object)

# %% [markdown]
# **Create a corrections dictionary and apply to Store names**

# %%
store_corrections = {
    "bufalo wings": "buffalo wings",
    "crepes & waffle": "crepes & waffles",
    "dunkin": "dunkin donuts",
    "corral": "el corral",
    "dunot factory": "donut factory",
    "vital home - food": "vital home",
    "minca - taller": "minca",
    "la 75": "la75",
    "apple": "icloud",
    "gas tds": "vanti",
    "sanitas premium": "eps premium",
    "uber - pet": "uber",
    "icloid": "icloud",
    "ellinika": "nectaria",
    "cinabond": "foodology",
    "little caesrs": "little caesar",
    "sanitas": "bono eps",
    "guru": "gurus",
    "oxo": "oxxo",
    "carnal": "el carnal",
    "stabucks": "starbucks",
    "rappi - mcdonalds": "rappi",
    "burguer king": "burger king",
    "burger king'": "burger king",
    "luz tds": "enel",
    "carbon y xilvestre": "carbon & xilvestre",
    "colsubsicio": "colsubsidio",
    "decathelon": "decathalon",
    "disney +": "disney+",
    "don rom": "don romero",
    "exito wow": "exito",
    "kuty": "kutty",
    "la burra del gordo": "la birra del gordo",
    "sipote": "sipote burrito",
    "suchi nogal": "sushi nogal",
    "vital home": "vitalhome"
}

raw_df['Store'] = raw_df['Store'].replace(store_corrections)

# %% [markdown]
# **Sort Type  information and display unique values to identify misppeling and similar errors**

# %%
raw_df = raw_df.sort_values(by=['Type'])
raw_df_relation = raw_df['Type'].unique()
raw_df_relation
# Out:
# array(['beauty', 'clothing', 'cloud Services', 'dog', 'entertainment',
#        'gift', 'groceries', 'healthcare', 'home shopping', 'nan', 'none',
#        'papeleria', 'parking', 'party', 'prestamo', 'restaurant', 'snack',
#        'training', 'transportation', 'utilities'], dtype=object)

# %% [markdown]
# **Create a corrections dictionary and apply to Type names**

# %%
type_corrections = {
    "brunch": "restaurant",
    "utility": "utilities",
    "parra": "prestamo",
    "restaurants": "restaurant",
    "cellphone service": "utilities",
    "nutricionist": "healthcare",
    "dog food": "dog",
    "dog care": "dog",
    "dogs": "dog",
    "entretaiment": "entertainment",
    "entretainment": "entertainment",
    "food shopping": "groceries",
    "homeshoping": "home shopping",
    "medicine": "healthcare",
    "custome": "gift",
    "agua": "groceries",
    "delivery": "transportation",
    "storage": "cloud Services",
    "gym": "healthcare",
    "thanksgiving": "party"
}

raw_df['Type'] = raw_df['Type'].replace(type_corrections)

# %%
filtered_df = raw_df[raw_df['Type'] == 'storage']
filtered_df
# Out:
#            Date   Store     Type    Total
# 1019 2025-02-28  icloud  storage  12900.0
# 995  2025-01-29  icloud  storage  12900.0
